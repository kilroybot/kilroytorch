# %% [markdown]
# # Sequential Actor-Critic Example

# %% [markdown]
# ##### Imports

# %%
import warnings
from tqdm import TqdmWarning
warnings.filterwarnings("ignore", category=TqdmWarning)

# %%
import numpy as np
import torch
from torch import nn, optim
from tqdm import tqdm
from kilroyplot.plot import plt
from kilroyshare.codec import Codec
from kilroytorch.modules.offline.sequential import SimpleSequentialOfflineModule as OfflineModule
from kilroytorch.modules.online.sequential import ActorCriticSequentialOnlineModule as OnlineModule
from kilroytorch.models.distribution.sequential import LSTMSequentialDistributionModel as DistributionModel
from kilroytorch.models.reward.sequential import LSTMSequentialRewardModel as RewardModel
from kilroytorch.generator import Generator
from kilroytorch.utils import unpack_to_list

# %% [markdown]
# ##### Helpers

# %%
def position_values(xs, positions):
    return [[x[i] for x in xs if len(x) > i] for i in positions]

def natural_bins(a, b=None):
    a, b = (0, a) if b is None else (a, b)
    return np.arange(a-0.5, b+1)

def class_bins(n_classes):
    return natural_bins(0, n_classes-1)
    
def chunks(data, size):
    for i in range(0, len(data), size):
        yield data[i:i + size]

def generate(model, codec, n):
    return [codec.encode(sample) for sample in unpack_to_list(model.sample(n)[0])]

# %% [markdown]
# ## Task

# %% [markdown]
# Let's assume the values of the score function for all classes are like shown below.

# %%
n_classes = 5
max_length = 10

# %%
score = lambda value: -1 if len(value) > 5 else value.count(4) + value.count(3)

# %%
sequences = [[0, 1], [0, 2, 1], [0, 4, 1], [0, 4, 4, 1], [0, 4, 4, 4, 1], [0, 4, 4, 4, 4, 1]]
plt.scatter([score(seq) for seq in sequences], [str(seq) for seq in sequences])
plt.title("Exemplary scores")
plt.xlabel("score")
plt.ylabel("sequence")
# Out:
# Text(0, 0.5, 'sequence')

# %% [markdown]
# ## Model

# %%
class DummyCodec(Codec):    
    def encode(self, value):
        return value.flatten().tolist()

    def decode(self, value):
        return torch.tensor(value).view(-1, 1)

# %%
actor = DistributionModel(n_classes, Generator(max_length=max_length))
critic = RewardModel(n_classes)
codec = DummyCodec()
offline_module = OfflineModule(
    actor, 
    codec, 
    optim.Adam(actor.parameters(), lr=0.05)
)
online_module = OnlineModule(
    actor, 
    critic, 
    codec, 
    (optim.Adam(actor.parameters(), lr=0.0005), optim.Adam(critic.parameters(), lr=0.0005)),
    actor_iterations=1
)

# %% [markdown]
# ## Offline

# %% [markdown]
# Let's assume real samples have each value in sequence (excluding start and end) sampled from binomial distribution and sequences are maximum length.

# %%
n_samples = 1000
samples = np.hstack((
    np.zeros((n_samples, 1)),
    np.random.binomial(n_classes-3, 0.5, (n_samples, (max_length // 2)-2)) + 2,
    np.ones((n_samples, 1))
)).astype(int)

# %%
plt.hist(position_values(samples, range(max_length)), bins=class_bins(n_classes))
plt.title("Histogram of values at different positions in sequences from samples")
plt.xlabel("class")
plt.ylabel("frequency")
plt.legend(range(max_length), title="position")
plt.tight_layout()

# %%
n_epochs = 100
batch_size = 512
losses = []

for _ in tqdm(range(n_epochs)):
    epoch_losses = []
    for batch in chunks(samples, batch_size):
        metrics = offline_module.fit(batch)
        epoch_losses.append(metrics["loss"])
        offline_module = offline_module.step()
    losses.append(np.mean(epoch_losses))
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 34.15it/s]

# %%
plt.plot(losses)
plt.title("Mean loss each epoch")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.tight_layout()

# %%
samples = generate(actor, codec, 1000)

# %%
plt.hist(position_values(samples, range(max_length)), bins=class_bins(n_classes))
plt.title("Histogram of values at different positions in sequences from samples")
plt.xlabel("class")
plt.ylabel("frequency")
plt.legend(range(max_length), title="position")
plt.tight_layout()

# %%
plt.hist([len(s) for s in samples], bins=natural_bins(max_length))
plt.title("Histogram of samples lengths")
plt.xlabel("length")
plt.ylabel("frequency")
plt.tight_layout()

# %% [markdown]
# ## Online

# %%
n_iters = 1000
iter_size = 32
critic_losses = []
actor_losses = []
mean_scores = []

for _ in tqdm(range(n_iters)):
    scores = {
        key: score(value) for key, value in online_module.sample(iter_size)
    }
    mean_scores.append(np.mean(list(scores.values())))
    metrics = online_module.fit(scores)
    critic_losses.append(metrics["critic_loss"])
    actor_losses.append(metrics["actor_loss"])
    online_module = online_module.step()
# Out:
# 100%|██████████| 1000/1000 [01:10<00:00, 14.21it/s]

# %%
plt.plot(critic_losses)
plt.title("Critic loss each iteration")
plt.xlabel("iteration")
plt.ylabel("loss")
plt.tight_layout()

# %%
plt.plot(actor_losses)
plt.title("Actor loss each iteration")
plt.xlabel("iteration")
plt.ylabel("loss")
plt.tight_layout()

# %%
plt.plot(mean_scores)
plt.title("Mean scores of generated samples")
plt.xlabel("iteration")
plt.ylabel("mean score")
plt.tight_layout()

# %%
samples = generate(actor, codec, 1000)

# %%
plt.hist(position_values(samples, range(max_length)), bins=class_bins(n_classes))
plt.title("Histogram of values at different positions in sequences from samples")
plt.xlabel("class")
plt.ylabel("frequency")
plt.legend(range(max_length), title="position")
plt.tight_layout()

# %%
plt.hist([len(s) for s in samples], bins=natural_bins(max_length))
plt.title("Histogram of samples lengths")
plt.xlabel("length")
plt.ylabel("frequency")
plt.tight_layout()
